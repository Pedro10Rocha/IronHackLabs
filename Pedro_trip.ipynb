# %%
input("Your Name:")

# %% [markdown]
# introduce someone and her/his holidays preference

# %% [markdown]
# # Trip to Sahra
#
# A friend of mine, the fotographer Douglas Pingituro travelled to the Saara's desert in 2021 and the pictures of a wreck just blowed my mind

# %% [markdown]
# ![wreck.jpg](attachment:wreck.jpg)

# %% [markdown]
# ![wreck2.jpg](attachment:wreck2.jpg)

# %% [markdown]
# This wreck is located in El Marsa, Morocco.

# %% [markdown]
# ![Desert.jpg](attachment:Desert.jpg)

# %% [markdown]
# He was amazed by the hospitality of the nomad tribes the live in Sahra

# %% [markdown]
# https://www.youtube.com/watch?v=KGDRnLfCFNA

# %% [markdown]
# His Instagram page, if you want to follow his work :)
# [https://www.instagram.com/pingituro/]
